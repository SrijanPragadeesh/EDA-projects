# %%
# Import the libraries we need
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/superstore.csv', encoding='latin1')

# Display the first 5 rows
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
# Find the total Sales for each Category
category_sales = df.groupby('Category')['Sales'].sum()

# Display the result
category_sales
# Out:
# Category
# Furniture          1.153425e+06
# Office Supplies    1.111562e+06
# Technology         1.265369e+06
# Name: Sales, dtype: float64

# %%
# Create a bar plot
category_sales.plot(kind='bar')

plt.title('Total Sales for Each Category')
plt.xlabel('Category')
plt.ylabel('Total Sales')
plt.show()

# %%
# Create a box plot for Profit
plt.boxplot(df['Profit'])

plt.title('Profit Distribution')
plt.ylabel('Profit')
plt.show()

# %%
# Create a scatter plot
plt.scatter(df['Discount'], df['Profit'])

plt.title('Discount vs Profit')
plt.xlabel('Discount')
plt.ylabel('Profit')
plt.show()

# %%
# Select numerical columns
numerical_data = df.select_dtypes(include='number')

# Create the correlation matrix
correlation_matrix = numerical_data.corr()

# Display the correlation matrix
correlation_matrix
# Out:
#                Row ID  Postal Code     Sales  Quantity  Discount    Profit
# Row ID       1.000000     0.005188  0.000235 -0.002158  0.019255  0.009842
# Postal Code  0.005188     1.000000 -0.024207  0.010703  0.055237 -0.029254
# Sales        0.000235    -0.024207  1.000000  0.203273 -0.032799  0.525321
# Quantity    -0.002158     0.010703  0.203273  1.000000  0.008809  0.065279
# Discount     0.019255     0.055237 -0.032799  0.008809  1.000000 -0.214189
# Profit       0.009842    -0.029254  0.525321  0.065279 -0.214189  1.000000

# %%
# Create a heatmap
sns.heatmap(correlation_matrix, annot=True)

plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
# Find total Profit for each Category
category_profit = df.groupby('Category')['Profit'].sum()

# Find the category with the highest total Profit
highest_profit_category = category_profit.idxmax()
highest_profit = category_profit.max()

print('Category with the highest total Profit:', highest_profit_category)
print('Total Profit:', highest_profit)
# Out:
# Category with the highest total Profit: Technology
# Total Profit: 232897.5265

# %% [markdown]
# ## 8. Three Simple Business Insights
#
# ### Insight 1
# The category with the highest total sales is an important category because it contributes the most revenue.
#
# ### Insight 2
# The box plot shows that Profit has some very high and very low values, which means profit can vary a lot between orders.
#
# ### Insight 3
# The Discount vs Profit scatter plot can help us understand the effect of discounts on profit. Higher discounts may be linked with lower profits in some orders.
